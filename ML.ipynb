# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
# %matplotlib inline

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Resnet-18 architecture. In ResNet-18, the number of the residual blocks used in conv2_x, conv3_x, conv4_x conv5_x is 2, 2, 2 and 2.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
#import resnet18 for cifar10
import resnet
# Out:
# resnet18_model: ResNet18(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# Resnet-19 architecture
# ![image.png](attachment:image.png)

# %%
#CIFAR10 dataset preparation
import dataset
# %matplotlib inline

# %%
#Train Resnet18 for CIFAR10 
import train
# Out:
# Epoch [0/10], Step [100/195], Loss: 1.4472
# TRAIN LOSS : 1.5889
# TRAIN ACCURACY : 0.42
# train-loss: 1.5889, train-acc: 42.3598
# validation acc: 49.5092
#
#
# Epoch [1/10], Step [100/195], Loss: 1.1709
# TRAIN LOSS : 1.1437
# TRAIN ACCURACY : 0.59
# train-loss: 1.3663, train-acc: 59.1927
# validation acc: 62.0092
#
#
# Epoch [2/10], Step [100/195], Loss: 0.8953
# TRAIN LOSS : 0.9300
# TRAIN ACCURACY : 0.67
# train-loss: 1.2208, train-acc: 67.2616
# validation acc: 64.9740
#
#
# Epoch [3/10], Step [100/195], Loss: 0.7366
# TRAIN LOSS : 0.7869
# TRAIN ACCURACY : 0.72
# train-loss: 1.1124, train-acc: 72.2977
# validation acc: 69.7115
#
#
# Epoch [4/10], Step [100/195], Loss: 0.6023
# TRAIN LOSS : 0.6783
# TRAIN ACCURACY : 0.76
# train-loss: 1.0255, train-acc: 76.3762
# validation acc: 73.1671
#
#
# Epoch [5/10], Step [100/195], Loss: 0.5620
# TRAIN LOSS : 0.5840
# TRAIN ACCURACY : 0.80
# train-loss: 0.9520, train-acc: 79.5152
# validation acc: 73.9183
#
#
# ...

# %%
# Plot accuracy and loss during training and validation step

import plot_metrics
